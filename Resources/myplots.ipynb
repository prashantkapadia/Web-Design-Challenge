# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Load in csv
cities = pd.read_csv("Resources/cities.csv")
cities.head()
# Out:
#    City_ID          City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0  jacareacanga           0      BR  1528902000        62  -6.22
# 1        1    kaitangata         100      NZ  1528905304        94 -46.28
# 2        2      goulburn          20      AU  1528905078        91 -34.75
# 3        3          lata          76      IN  1528905305        89  30.78
# 4        4    chokurdakh           0      RU  1528905306        88  70.62
#
#       Lng  Max Temp  Wind Speed
# 0  -57.76     89.60        6.93
# 1  169.85     42.61        5.64
# 2  149.72     44.32       10.11
# 3   78.62     59.89        0.94
# 4  147.90     32.17        2.95

# %%
# Tells matplotlib that we want to make a scatter plot
# Latitude vs. Temperature[F]
# %matplotlib notebook
temp = cities['Max Temp']
comp1 = plt.scatter(cities.Lat, temp, marker="o", facecolors="grey", edgecolors="black",alpha=0.75)
plt.title("City Latitude Vs. Maximum Temperature[F]")
plt.xlabel("Latitude")
plt.ylabel("Temperature[F]")
plt.ylim(0, 120)
plt.xlim(-60, 90)
plt.savefig("Images/LatVsMaxTemp.png")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Latitude vs. Humidity[%] scatter plot.
# %matplotlib notebook

comp2 = plt.scatter(cities.Lat, cities.Humidity, marker="o", facecolors="grey", edgecolors="black",alpha=0.75)

plt.title("City Latitude Vs. Humidity[%]")
plt.xlabel("Latitude")
plt.ylabel("Humidity[%]")

plt.ylim(0, 120)
plt.xlim(-60, 90)
plt.show()
plt.tight_layout()
plt.savefig("Images/LatVsHumidity.png")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#comp2 = cities.plot(kind="scatter", x="Latitude", y="Humidity",title="Latitude Vs. Humidity")
#plt.show()
#plt.tight_layout()

# %%
# Latitude vs. Cloudiness [%] scatter plot.
# %matplotlib notebook
comp3 = plt.scatter(cities.Lat, cities.Cloudiness,facecolors="grey", edgecolors="black",alpha=0.75)

plt.title("City Latitude Vs. Cloudiness[%]")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness[%]")

plt.ylim(0, 120)
plt.xlim(-60, 90)

plt.savefig("Images/LatVsCloudiness.png")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
cities
# Out:
#      City_ID          City  Cloudiness Country        Date  Humidity    Lat  \
# 0          0  jacareacanga           0      BR  1528902000        62  -6.22
# 1          1    kaitangata         100      NZ  1528905304        94 -46.28
# 2          2      goulburn          20      AU  1528905078        91 -34.75
# 3          3          lata          76      IN  1528905305        89  30.78
# 4          4    chokurdakh           0      RU  1528905306        88  70.62
# ..       ...           ...         ...     ...         ...       ...    ...
# 542      542        scalea          36      IT  1528905631       100  39.82
# 543      543    san andres          68      PH  1528905632       100  13.32
# 544      544        muisne          92      EC  1528905633        84   0.61
# 545      545           ati          20      TD  1528905633        25  13.21
# 546      546      san luis           0      AR  1528905472        53 -33.30
#
#         Lng  Max Temp  Wind Speed
# ...

# %%
# Latitude vs. Wind Speed[mph]scatter plot.
# %matplotlib notebook

wind = cities['Wind Speed']

comp4 = plt.scatter(cities.Lat,wind,facecolors="grey", edgecolors="black",alpha=0.75)

plt.title("City Latitude Vs. Wind Speed [mph]")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed [mph]")

plt.ylim(0, 35)
plt.xlim(-60, 90)

plt.savefig("Images/LatVsWindSpeed.png")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Existing Data Frame to to html
# render dataframe as html
html = cities.to_html()
print(html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City_ID</th>
#       <th>City</th>
#       <th>Cloudiness</th>
#       <th>Country</th>
#       <th>Date</th>
#       <th>Humidity</th>
#       <th>Lat</th>
#       <th>Lng</th>
#       <th>Max Temp</th>
#       <th>Wind Speed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>jacareacanga</td>
#       <td>0</td>
#       <td>BR</td>
#       <td>1528902000</td>
#       <td>62</td>
#       <td>-6.22</td>
#       <td>-57.76</td>
#       <td>89.60</td>
#       <td>6.93</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>kaitangata</td>
#       <td>100</td>
#       <td>NZ</td>
#       <td>1528905304</td>
#       <td>94</td>
#       <td>-46.28</td>
#       <td>169.85</td>
#       <td>42.61</td>
#       <td>5.64</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
# ...
